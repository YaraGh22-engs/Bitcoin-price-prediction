# %% [markdown]
# <a href="https://colab.research.google.com/github/yara-esmaiel/Bitcoin-price-prediction/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# First we will import the necessary Library 

import os
import pandas as pd
import numpy as np
import math
import datetime as dt
import matplotlib.pyplot as plt


# For Evalution we will use these library

from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score 
from sklearn.metrics import mean_poisson_deviance, mean_gamma_deviance, accuracy_score
from sklearn.preprocessing import MinMaxScaler

# For model building we will use these library

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM


# For PLotting we will use these library

import matplotlib.pyplot as plt
from itertools import cycle
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
from plotly.offline import plot, iplot, init_notebook_mode
import plotly.graph_objs as go
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import plotly.io as pio

pio.renderers
pio.renderers.default = "svg"

# %%
from numpy.random import seed
seed(1)
from tensorflow import keras
SEED = 1
keras.utils.set_random_seed(SEED)

# %%
from numpy.random import seed
seed(1)
from tensorflow import random
random.set_seed(1)

# %%
# Load our dataset 
# Note it should be in same dir


maindf=pd.read_csv('/content/drive/MyDrive/BTC/BTC-USD from2014 to 24-6-2022.csv')

# %%
# Printing the start date and End date of the dataset

sd=maindf.iloc[0][0]
ed=maindf.iloc[-1][0]


print('Starting Date',sd)
print('Ending Date',ed)
# Out:
# Starting Date 2014-09-17
# Ending Date 2022-06-24

# %%
# Lets First Take all the Close Price 
closedf = maindf[['Date','Close']]
print("Shape of close dataframe:", closedf.shape)
# Out:
# Shape of close dataframe: (2838, 2)

# %%
#Now we will Take data of just 1 Year

closedf = closedf[(closedf['Date'] > '2015-01-1') & (closedf['Date'] < '2022-06-15')]
close_stock = closedf.copy()
print("Total data for prediction: ",closedf.shape[0])
# Out:
# Total data for prediction:  2713

# %%
# deleting date column and normalizing using MinMax Scaler

del closedf['Date']
realdf=closedf
scaler=MinMaxScaler(feature_range=(0,1))
closedf=scaler.fit_transform(np.array(closedf).reshape(-1,1))
print(closedf.shape)
print(closedf)
# Out:
# (2713, 1)
# [[0.00143485]
#  [0.00129928]
#  [0.00133098]
#  ...
#  [0.39449545]
#  [0.33105368]
#  [0.32688985]]

# %%
# we keep the training set as 60% and 40% testing set

training_size=int(len(closedf)*0.60)
test_size=len(closedf)-training_size
train_data,test_data=closedf[0:training_size,:],closedf[training_size:len(closedf),:1]
print("train_data: ", train_data.shape)
print("test_data: ", test_data.shape)
#print("train_data: ", train_data)
#print("test_data: ", test_data)
# Out:
# train_data:  (1627, 1)
# test_data:  (1086, 1)

# %%
# convert an array of values into a dataset matrix

def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 15
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_test: ", X_test.shape)
print("y_test", y_test.shape)
# Out:
# X_train:  (1611, 15)
# y_train:  (1611,)
# X_test:  (1070, 15)
# y_test (1070,)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

print("X_train: ", X_train.shape)
print("X_test: ", X_test.shape)
# Out:
# X_train:  (1611, 15, 1)
# X_test:  (1070, 15, 1)

# %%
y_test
# Out:
# array([0.17775095, 0.16591142, 0.17269778, ..., 0.41821102, 0.39449545,
#        0.33105368])

# %%
import time
import numpy as np
import tensorflow as tf
from tensorflow.keras.losses import Loss
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization, Flatten
from tensorflow.compat.v1.keras.layers import CuDNNLSTM
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint

def custom_loss(y_true, y_pred):

    mse = tf.keras.losses.MeanSquaredError()

    penalty = 10

    # add slightly more penalty if prediction overshoots actual in any direction
    loss = tf.where(
        condition=tf.less(y_pred, y_true),
        x=mse(y_true, y_pred) * penalty/5,
        y=mse(y_true, y_pred) * penalty/10
    )

    return loss

EPOCHS = 350
BATCH_SIZE = 32
MODEL_NAME = f"MODEL 01-{str(int(time.time()))}"

# %%
import keras.backend as K
from keras.callbacks import ModelCheckpoint, EarlyStopping

from keras.layers import Dense, LSTM, Dropout
# Actuall modelLSTM Building
modelLSTM=Sequential()

modelLSTM.add(LSTM(128,input_shape=(X_train.shape[1], 1),activation="relu",return_sequences=True))
modelLSTM.add(LSTM(units = 64, input_shape = (X_train.shape[1], 1),activation="relu"))
modelLSTM.add(Dense(1))


opt = tf.keras.optimizers.Adam(learning_rate=1e-3, decay=1e-6)

checkpoint_path_2_15 = 'my_best_model_2_15.hdf5'

metric= tf.keras.metrics.MeanSquaredError()

modelLSTM.compile(loss=custom_loss, optimizer=opt, metrics=[metric]) 

val_metric = 'val_'+metric.name


checkpoint15 = ModelCheckpoint(filepath=checkpoint_path_2_15, monitor=val_metric, verbose=1,save_best_only=True, mode='min',metric=metric)


earlystopping = EarlyStopping(monitor=val_metric, patience=100, restore_best_weights=True)

callbacks = [checkpoint15, earlystopping]

# %%
history = modelLSTM.fit(X_train, y_train, 
                    batch_size=BATCH_SIZE,
                    epochs=300, 
                    validation_data=(X_test, y_test),
                    shuffle=False,
                    callbacks= callbacks)
# Out:
# Epoch 1/300
# 50/51 [============================>.] - ETA: 0s - loss: 0.0031 - mean_squared_error: 0.0019
# Epoch 1: val_mean_squared_error improved from inf to 0.12944, saving model to my_best_model_2_15.hdf5
# 51/51 [==============================] - 5s 43ms/step - loss: 0.0031 - mean_squared_error: 0.0019 - val_loss: 0.2589 - val_mean_squared_error: 0.1294
# Epoch 2/300
# 49/51 [===========================>..] - ETA: 0s - loss: 0.0040 - mean_squared_error: 0.0027
# Epoch 2: val_mean_squared_error did not improve from 0.12944
# 51/51 [==============================] - 2s 33ms/step - loss: 0.0039 - mean_squared_error: 0.0026 - val_loss: 0.2816 - val_mean_squared_error: 0.1408
# Epoch 3/300
# 51/51 [==============================] - ETA: 0s - loss: 0.0038 - mean_squared_error: 0.0027
# Epoch 3: val_mean_squared_error improved from 0.12944 to 0.11055, saving model to my_best_model_2_15.hdf5
# 51/51 [==============================] - 2s 33ms/step - loss: 0.0038 - mean_squared_error: 0.0027 - val_loss: 0.2211 - val_mean_squared_error: 0.1105
# Epoch 4/300
# 49/51 [===========================>..] - ETA: 0s - loss: 0.0055 - mean_squared_error: 0.0036
# Epoch 4: val_mean_squared_error improved from 0.11055 to 0.09494, saving model to my_best_model_2_15.hdf5
# 51/51 [==============================] - 2s 34ms/step - loss: 0.0054 - mean_squared_error: 0.0035 - val_loss: 0.1898 - val_mean_squared_error: 0.0949
# Epoch 5/300
# 49/51 [===========================>..] - ETA: 0s - loss: 0.0055 - mean_squared_error: 0.0039
# Epoch 5: val_mean_squared_error did not improve from 0.09494
# 51/51 [==============================] - 2s 33ms/step - loss: 0.0054 - mean_squared_error: 0.0038 - val_loss: 0.2713 - val_mean_squared_error: 0.1357
# Epoch 6/300
# 51/51 [==============================] - ETA: 0s - loss: 0.0046 - mean_squared_error: 0.0030
# Epoch 6: val_mean_squared_error did not improve from 0.09494
# 51/51 [==============================] - 2s 34ms/step - loss: 0.0046 - mean_squared_error: 0.0030 - val_loss: 0.2103 - val_mean_squared_error: 0.1052
# Epoch 7/300
# 51/51 [==============================] - ETA: 0s - loss: 0.0062 - mean_squared_error: 0.0041
# Epoch 7: val_mean_squared_error improved from 0.09494 to 0.09084, saving model to my_best_model_2_15.hdf5
# 51/51 [==============================] - 2s 34ms/step - loss: 0.0062 - mean_squared_error: 0.0041 - val_loss: 0.1817 - val_mean_squared_error: 0.0908
# Epoch 8/300
# 49/51 [===========================>..] - ETA: 0s - loss: 0.0052 - mean_squared_error: 0.0040
# Epoch 8: val_mean_squared_error improved from 0.09084 to 0.05616, saving model to my_best_model_2_15.hdf5
# 51/51 [==============================] - 2s 33ms/step - loss: 0.0051 - mean_squared_error: 0.0039 - val_loss: 0.1123 - val_mean_squared_error: 0.0562
# Epoch 9/300
# 51/51 [==============================] - ETA: 0s - loss: 0.0050 - mean_squared_error: 0.0033
# Epoch 9: val_mean_squared_error improved from 0.05616 to 0.02845, saving model to my_best_model_2_15.hdf5
# 51/51 [==============================] - 2s 35ms/step - loss: 0.0050 - mean_squared_error: 0.0033 - val_loss: 0.0568 - val_mean_squared_error: 0.0284
# Epoch 10/300
# 51/51 [==============================] - ETA: 0s - loss: 0.0037 - mean_squared_error: 0.0027
# Epoch 10: val_mean_squared_error improved from 0.02845 to 0.00433, saving model to my_best_model_2_15.hdf5
# 51/51 [==============================] - 2s 35ms/step - loss: 0.0037 - mean_squared_error: 0.0027 - val_loss: 0.0064 - val_mean_squared_error: 0.0043
# Epoch 11/300
# 51/51 [==============================] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0014
# Epoch 11: val_mean_squared_error did not improve from 0.00433
# 51/51 [==============================] - 2s 34ms/step - loss: 0.0019 - mean_squared_error: 0.0014 - val_loss: 0.0322 - val_mean_squared_error: 0.0313
# Epoch 12/300
# 51/51 [==============================] - ETA: 0s - loss: 0.0011 - mean_squared_error: 8.1868e-04
# Epoch 12: val_mean_squared_error did not improve from 0.00433
# 51/51 [==============================] - 2s 33ms/step - loss: 0.0011 - mean_squared_error: 8.1868e-04 - val_loss: 0.1812 - val_mean_squared_error: 0.1805
# Epoch 13/300
# 49/51 [===========================>..] - ETA: 0s - loss: 6.8591e-04 - mean_squared_error: 5.0245e-04
# Epoch 13: val_mean_squared_error did not improve from 0.00433
# 51/51 [==============================] - 2s 33ms/step - loss: 6.7605e-04 - mean_squared_error: 4.9356e-04 - val_loss: 0.4067 - val_mean_squared_error: 0.4062
# Epoch 14/300
# 51/51 [==============================] - ETA: 0s - loss: 4.8556e-04 - mean_squared_error: 3.4718e-04
# Epoch 14: val_mean_squared_error did not improve from 0.00433
# 51/51 [==============================] - 2s 34ms/step - loss: 4.8556e-04 - mean_squared_error: 3.4718e-04 - val_loss: 0.3698 - val_mean_squared_error: 0.3693
# Epoch 15/300
# 49/51 [===========================>..] - ETA: 0s - loss: 4.1431e-04 - mean_squared_error: 2.9485e-04
# Epoch 15: val_mean_squared_error did not improve from 0.00433
# 51/51 [==============================] - 2s 34ms/step - loss: 4.1632e-04 - mean_squared_error: 2.9376e-04 - val_loss: 0.2425 - val_mean_squared_error: 0.2418
# Epoch 16/300
# 51/51 [==============================] - ETA: 0s - loss: 3.6799e-04 - mean_squared_error: 2.5892e-04
# Epoch 16: val_mean_squared_error did not improve from 0.00433
# 51/51 [==============================] - 2s 34ms/step - loss: 3.6799e-04 - mean_squared_error: 2.5892e-04 - val_loss: 0.1611 - val_mean_squared_error: 0.1604
# Epoch 17/300
# 51/51 [==============================] - ETA: 0s - loss: 3.2271e-04 - mean_squared_error: 2.2602e-04
# Epoch 17: val_mean_squared_error did not improve from 0.00433
# 51/51 [==============================] - 2s 34ms/step - loss: 3.2271e-04 - mean_squared_error: 2.2602e-04 - val_loss: 0.0901 - val_mean_squared_error: 0.0892
# Epoch 18/300
# 51/51 [==============================] - ETA: 0s - loss: 2.9142e-04 - mean_squared_error: 2.0409e-04
# Epoch 18: val_mean_squared_error did not improve from 0.00433
# 51/51 [==============================] - 2s 34ms/step - loss: 2.9142e-04 - mean_squared_error: 2.0409e-04 - val_loss: 0.0607 - val_mean_squared_error: 0.0600
# Epoch 19/300
# 49/51 [===========================>..] - ETA: 0s - loss: 2.2254e-04 - mean_squared_error: 1.5882e-04
# Epoch 19: val_mean_squared_error did not improve from 0.00433
# 51/51 [==============================] - 2s 34ms/step - loss: 2.3693e-04 - mean_squared_error: 1.6482e-04 - val_loss: 0.0325 - val_mean_squared_error: 0.0316
# Epoch 20/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.9100e-04 - mean_squared_error: 1.3610e-04
# Epoch 20: val_mean_squared_error did not improve from 0.00433
# 51/51 [==============================] - 2s 33ms/step - loss: 2.0909e-04 - mean_squared_error: 1.4407e-04 - val_loss: 0.0162 - val_mean_squared_error: 0.0150
# Epoch 21/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.6706e-04 - mean_squared_error: 1.1817e-04
# Epoch 21: val_mean_squared_error did not improve from 0.00433
# 51/51 [==============================] - 2s 33ms/step - loss: 1.8620e-04 - mean_squared_error: 1.2682e-04 - val_loss: 0.0096 - val_mean_squared_error: 0.0082
# Epoch 22/300
# 51/51 [==============================] - ETA: 0s - loss: 1.7388e-04 - mean_squared_error: 1.1729e-04
# Epoch 22: val_mean_squared_error improved from 0.00433 to 0.00369, saving model to my_best_model_2_15.hdf5
# 51/51 [==============================] - 2s 34ms/step - loss: 1.7388e-04 - mean_squared_error: 1.1729e-04 - val_loss: 0.0061 - val_mean_squared_error: 0.0037
# Epoch 23/300
# 51/51 [==============================] - ETA: 0s - loss: 1.6562e-04 - mean_squared_error: 1.1599e-04
# Epoch 23: val_mean_squared_error did not improve from 0.00369
# 51/51 [==============================] - 2s 34ms/step - loss: 1.6562e-04 - mean_squared_error: 1.1599e-04 - val_loss: 0.0102 - val_mean_squared_error: 0.0052
# Epoch 24/300
# 51/51 [==============================] - ETA: 0s - loss: 1.8374e-04 - mean_squared_error: 1.3090e-04
# Epoch 24: val_mean_squared_error did not improve from 0.00369
# 51/51 [==============================] - 2s 34ms/step - loss: 1.8374e-04 - mean_squared_error: 1.3090e-04 - val_loss: 0.0196 - val_mean_squared_error: 0.0098
# Epoch 25/300
# 51/51 [==============================] - ETA: 0s - loss: 1.8536e-04 - mean_squared_error: 1.3181e-04
# Epoch 25: val_mean_squared_error did not improve from 0.00369
# 51/51 [==============================] - 2s 34ms/step - loss: 1.8536e-04 - mean_squared_error: 1.3181e-04 - val_loss: 0.0120 - val_mean_squared_error: 0.0061
# Epoch 26/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.6073e-04 - mean_squared_error: 1.1874e-04
# Epoch 26: val_mean_squared_error did not improve from 0.00369
# 51/51 [==============================] - 2s 38ms/step - loss: 1.7190e-04 - mean_squared_error: 1.2336e-04 - val_loss: 0.0124 - val_mean_squared_error: 0.0063
# Epoch 27/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.6555e-04 - mean_squared_error: 1.2355e-04
# Epoch 27: val_mean_squared_error did not improve from 0.00369
# 51/51 [==============================] - 3s 62ms/step - loss: 1.7564e-04 - mean_squared_error: 1.2763e-04 - val_loss: 0.0160 - val_mean_squared_error: 0.0080
# Epoch 28/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.6821e-04 - mean_squared_error: 1.2610e-04
# Epoch 28: val_mean_squared_error did not improve from 0.00369
# 51/51 [==============================] - 2s 42ms/step - loss: 1.7731e-04 - mean_squared_error: 1.2976e-04 - val_loss: 0.0181 - val_mean_squared_error: 0.0091
# Epoch 29/300
# 51/51 [==============================] - ETA: 0s - loss: 1.7739e-04 - mean_squared_error: 1.3029e-04
# Epoch 29: val_mean_squared_error did not improve from 0.00369
# 51/51 [==============================] - 2s 34ms/step - loss: 1.7739e-04 - mean_squared_error: 1.3029e-04 - val_loss: 0.0177 - val_mean_squared_error: 0.0089
# Epoch 30/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.7254e-04 - mean_squared_error: 1.3006e-04
# Epoch 30: val_mean_squared_error did not improve from 0.00369
# 51/51 [==============================] - 2s 35ms/step - loss: 1.7799e-04 - mean_squared_error: 1.3178e-04 - val_loss: 0.0184 - val_mean_squared_error: 0.0092
# Epoch 31/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.6984e-04 - mean_squared_error: 1.2933e-04
# Epoch 31: val_mean_squared_error did not improve from 0.00369
# 51/51 [==============================] - 2s 33ms/step - loss: 1.7587e-04 - mean_squared_error: 1.3134e-04 - val_loss: 0.0239 - val_mean_squared_error: 0.0120
# Epoch 32/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.8362e-04 - mean_squared_error: 1.3540e-04
# Epoch 32: val_mean_squared_error did not improve from 0.00369
# 51/51 [==============================] - 2s 33ms/step - loss: 1.8222e-04 - mean_squared_error: 1.3401e-04 - val_loss: 0.0208 - val_mean_squared_error: 0.0104
# Epoch 33/300
# 51/51 [==============================] - ETA: 0s - loss: 1.8313e-04 - mean_squared_error: 1.3017e-04
# Epoch 33: val_mean_squared_error did not improve from 0.00369
# 51/51 [==============================] - 2s 34ms/step - loss: 1.8313e-04 - mean_squared_error: 1.3017e-04 - val_loss: 0.0249 - val_mean_squared_error: 0.0124
# Epoch 34/300
# 51/51 [==============================] - ETA: 0s - loss: 2.0378e-04 - mean_squared_error: 1.4567e-04
# Epoch 34: val_mean_squared_error did not improve from 0.00369
# 51/51 [==============================] - 2s 34ms/step - loss: 2.0378e-04 - mean_squared_error: 1.4567e-04 - val_loss: 0.0273 - val_mean_squared_error: 0.0137
# Epoch 35/300
# 49/51 [===========================>..] - ETA: 0s - loss: 2.2151e-04 - mean_squared_error: 1.5949e-04
# Epoch 35: val_mean_squared_error improved from 0.00369 to 0.00213, saving model to my_best_model_2_15.hdf5
# 51/51 [==============================] - 2s 34ms/step - loss: 2.3678e-04 - mean_squared_error: 1.6582e-04 - val_loss: 0.0040 - val_mean_squared_error: 0.0021
# Epoch 36/300
# 51/51 [==============================] - ETA: 0s - loss: 1.8028e-04 - mean_squared_error: 1.3937e-04
# Epoch 36: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.8028e-04 - mean_squared_error: 1.3937e-04 - val_loss: 0.0255 - val_mean_squared_error: 0.0128
# Epoch 37/300
# 51/51 [==============================] - ETA: 0s - loss: 2.5051e-04 - mean_squared_error: 1.7451e-04
# Epoch 37: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 2.5051e-04 - mean_squared_error: 1.7451e-04 - val_loss: 0.0156 - val_mean_squared_error: 0.0079
# Epoch 38/300
# 49/51 [===========================>..] - ETA: 0s - loss: 2.5134e-04 - mean_squared_error: 1.8378e-04
# Epoch 38: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 2.6849e-04 - mean_squared_error: 1.9080e-04 - val_loss: 0.0078 - val_mean_squared_error: 0.0039
# Epoch 39/300
# 51/51 [==============================] - ETA: 0s - loss: 1.5865e-04 - mean_squared_error: 1.1862e-04
# Epoch 39: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.5865e-04 - mean_squared_error: 1.1862e-04 - val_loss: 0.0313 - val_mean_squared_error: 0.0156
# Epoch 40/300
# 51/51 [==============================] - ETA: 0s - loss: 1.8398e-04 - mean_squared_error: 1.4073e-04
# Epoch 40: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.8398e-04 - mean_squared_error: 1.4073e-04 - val_loss: 0.0244 - val_mean_squared_error: 0.0122
# Epoch 41/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.8437e-04 - mean_squared_error: 1.3414e-04
# Epoch 41: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 33ms/step - loss: 1.8275e-04 - mean_squared_error: 1.3314e-04 - val_loss: 0.0103 - val_mean_squared_error: 0.0052
# Epoch 42/300
# 51/51 [==============================] - ETA: 0s - loss: 1.5169e-04 - mean_squared_error: 1.1231e-04
# Epoch 42: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.5169e-04 - mean_squared_error: 1.1231e-04 - val_loss: 0.0118 - val_mean_squared_error: 0.0060
# Epoch 43/300
# 51/51 [==============================] - ETA: 0s - loss: 1.8359e-04 - mean_squared_error: 1.4199e-04
# Epoch 43: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.8359e-04 - mean_squared_error: 1.4199e-04 - val_loss: 0.0333 - val_mean_squared_error: 0.0167
# Epoch 44/300
# 51/51 [==============================] - ETA: 0s - loss: 1.8226e-04 - mean_squared_error: 1.4523e-04
# Epoch 44: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.8226e-04 - mean_squared_error: 1.4523e-04 - val_loss: 0.0434 - val_mean_squared_error: 0.0217
# Epoch 45/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.8253e-04 - mean_squared_error: 1.4273e-04
# Epoch 45: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.8046e-04 - mean_squared_error: 1.4097e-04 - val_loss: 0.0478 - val_mean_squared_error: 0.0239
# Epoch 46/300
# 51/51 [==============================] - ETA: 0s - loss: 1.8804e-04 - mean_squared_error: 1.3627e-04
# Epoch 46: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.8804e-04 - mean_squared_error: 1.3627e-04 - val_loss: 0.0279 - val_mean_squared_error: 0.0141
# Epoch 47/300
# 51/51 [==============================] - ETA: 0s - loss: 1.6583e-04 - mean_squared_error: 1.1574e-04
# Epoch 47: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.6583e-04 - mean_squared_error: 1.1574e-04 - val_loss: 0.0126 - val_mean_squared_error: 0.0064
# Epoch 48/300
# 51/51 [==============================] - ETA: 0s - loss: 2.3759e-04 - mean_squared_error: 1.7930e-04
# Epoch 48: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 2.3759e-04 - mean_squared_error: 1.7930e-04 - val_loss: 0.0831 - val_mean_squared_error: 0.0416
# Epoch 49/300
# 51/51 [==============================] - ETA: 0s - loss: 1.8956e-04 - mean_squared_error: 1.4402e-04
# Epoch 49: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 33ms/step - loss: 1.8956e-04 - mean_squared_error: 1.4402e-04 - val_loss: 0.0930 - val_mean_squared_error: 0.0465
# Epoch 50/300
# 51/51 [==============================] - ETA: 0s - loss: 1.9467e-04 - mean_squared_error: 1.5819e-04
# Epoch 50: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.9467e-04 - mean_squared_error: 1.5819e-04 - val_loss: 0.0682 - val_mean_squared_error: 0.0341
# Epoch 51/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.7767e-04 - mean_squared_error: 1.3981e-04
# Epoch 51: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 33ms/step - loss: 1.7552e-04 - mean_squared_error: 1.3795e-04 - val_loss: 0.0836 - val_mean_squared_error: 0.0418
# Epoch 52/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.8106e-04 - mean_squared_error: 1.4786e-04
# Epoch 52: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.8192e-04 - mean_squared_error: 1.4697e-04 - val_loss: 0.1016 - val_mean_squared_error: 0.0508
# Epoch 53/300
# 49/51 [===========================>..] - ETA: 0s - loss: 2.0531e-04 - mean_squared_error: 1.6400e-04
# Epoch 53: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 2.0630e-04 - mean_squared_error: 1.6300e-04 - val_loss: 0.2451 - val_mean_squared_error: 0.1226
# Epoch 54/300
# 49/51 [===========================>..] - ETA: 0s - loss: 2.3417e-04 - mean_squared_error: 1.8423e-04
# Epoch 54: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 33ms/step - loss: 2.3054e-04 - mean_squared_error: 1.8106e-04 - val_loss: 0.1873 - val_mean_squared_error: 0.0937
# Epoch 55/300
# 51/51 [==============================] - ETA: 0s - loss: 2.3323e-04 - mean_squared_error: 1.8186e-04
# Epoch 55: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 2.3323e-04 - mean_squared_error: 1.8186e-04 - val_loss: 0.0510 - val_mean_squared_error: 0.0255
# Epoch 56/300
# 51/51 [==============================] - ETA: 0s - loss: 1.8722e-04 - mean_squared_error: 1.4482e-04
# Epoch 56: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.8722e-04 - mean_squared_error: 1.4482e-04 - val_loss: 0.1397 - val_mean_squared_error: 0.0699
# Epoch 57/300
# 51/51 [==============================] - ETA: 0s - loss: 2.3460e-04 - mean_squared_error: 1.8016e-04
# Epoch 57: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 2.3460e-04 - mean_squared_error: 1.8016e-04 - val_loss: 0.0773 - val_mean_squared_error: 0.0387
# Epoch 58/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.5962e-04 - mean_squared_error: 1.2826e-04
# Epoch 58: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 33ms/step - loss: 1.7145e-04 - mean_squared_error: 1.3296e-04 - val_loss: 0.0806 - val_mean_squared_error: 0.0403
# Epoch 59/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.4985e-04 - mean_squared_error: 1.1603e-04
# Epoch 59: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 33ms/step - loss: 1.5041e-04 - mean_squared_error: 1.1540e-04 - val_loss: 0.1385 - val_mean_squared_error: 0.0693
# Epoch 60/300
# 51/51 [==============================] - ETA: 0s - loss: 1.9354e-04 - mean_squared_error: 1.5382e-04
# Epoch 60: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.9354e-04 - mean_squared_error: 1.5382e-04 - val_loss: 0.1207 - val_mean_squared_error: 0.0603
# Epoch 61/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.7118e-04 - mean_squared_error: 1.3525e-04
# Epoch 61: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.6933e-04 - mean_squared_error: 1.3340e-04 - val_loss: 0.0954 - val_mean_squared_error: 0.0477
# Epoch 62/300
# 51/51 [==============================] - ETA: 0s - loss: 1.6487e-04 - mean_squared_error: 1.2886e-04
# Epoch 62: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.6487e-04 - mean_squared_error: 1.2886e-04 - val_loss: 0.1283 - val_mean_squared_error: 0.0642
# Epoch 63/300
# 51/51 [==============================] - ETA: 0s - loss: 1.7530e-04 - mean_squared_error: 1.3939e-04
# Epoch 63: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.7530e-04 - mean_squared_error: 1.3939e-04 - val_loss: 0.2282 - val_mean_squared_error: 0.1141
# Epoch 64/300
# 51/51 [==============================] - ETA: 0s - loss: 2.0936e-04 - mean_squared_error: 1.6589e-04
# Epoch 64: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 33ms/step - loss: 2.0936e-04 - mean_squared_error: 1.6589e-04 - val_loss: 0.2968 - val_mean_squared_error: 0.1484
# Epoch 65/300
# 51/51 [==============================] - ETA: 0s - loss: 2.7485e-04 - mean_squared_error: 2.2328e-04
# Epoch 65: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 2.7485e-04 - mean_squared_error: 2.2328e-04 - val_loss: 0.0536 - val_mean_squared_error: 0.0268
# Epoch 66/300
# 51/51 [==============================] - ETA: 0s - loss: 2.1100e-04 - mean_squared_error: 1.6426e-04
# Epoch 66: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 2.1100e-04 - mean_squared_error: 1.6426e-04 - val_loss: 0.1482 - val_mean_squared_error: 0.0741
# Epoch 67/300
# 51/51 [==============================] - ETA: 0s - loss: 2.6075e-04 - mean_squared_error: 1.8931e-04
# Epoch 67: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 2.6075e-04 - mean_squared_error: 1.8931e-04 - val_loss: 0.0805 - val_mean_squared_error: 0.0403
# Epoch 68/300
# 51/51 [==============================] - ETA: 0s - loss: 2.1857e-04 - mean_squared_error: 1.7717e-04
# Epoch 68: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 2.1857e-04 - mean_squared_error: 1.7717e-04 - val_loss: 0.0542 - val_mean_squared_error: 0.0271
# Epoch 69/300
# 51/51 [==============================] - ETA: 0s - loss: 1.1141e-04 - mean_squared_error: 8.1921e-05
# Epoch 69: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.1141e-04 - mean_squared_error: 8.1921e-05 - val_loss: 0.0978 - val_mean_squared_error: 0.0489
# Epoch 70/300
# 51/51 [==============================] - ETA: 0s - loss: 1.5765e-04 - mean_squared_error: 1.2092e-04
# Epoch 70: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.5765e-04 - mean_squared_error: 1.2092e-04 - val_loss: 0.0971 - val_mean_squared_error: 0.0486
# Epoch 71/300
# 51/51 [==============================] - ETA: 0s - loss: 1.5491e-04 - mean_squared_error: 1.2243e-04
# Epoch 71: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.5491e-04 - mean_squared_error: 1.2243e-04 - val_loss: 0.0780 - val_mean_squared_error: 0.0390
# Epoch 72/300
# 51/51 [==============================] - ETA: 0s - loss: 1.8125e-04 - mean_squared_error: 1.4376e-04
# Epoch 72: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.8125e-04 - mean_squared_error: 1.4376e-04 - val_loss: 0.1294 - val_mean_squared_error: 0.0647
# Epoch 73/300
# 51/51 [==============================] - ETA: 0s - loss: 1.6940e-04 - mean_squared_error: 1.3503e-04
# Epoch 73: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.6940e-04 - mean_squared_error: 1.3503e-04 - val_loss: 0.1578 - val_mean_squared_error: 0.0789
# Epoch 74/300
# 51/51 [==============================] - ETA: 0s - loss: 1.9092e-04 - mean_squared_error: 1.5478e-04
# Epoch 74: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.9092e-04 - mean_squared_error: 1.5478e-04 - val_loss: 0.1253 - val_mean_squared_error: 0.0627
# Epoch 75/300
# 51/51 [==============================] - ETA: 0s - loss: 1.6617e-04 - mean_squared_error: 1.3249e-04
# Epoch 75: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.6617e-04 - mean_squared_error: 1.3249e-04 - val_loss: 0.1697 - val_mean_squared_error: 0.0849
# Epoch 76/300
# 51/51 [==============================] - ETA: 0s - loss: 1.9455e-04 - mean_squared_error: 1.5797e-04
# Epoch 76: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.9455e-04 - mean_squared_error: 1.5797e-04 - val_loss: 0.0992 - val_mean_squared_error: 0.0496
# Epoch 77/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.5248e-04 - mean_squared_error: 1.2193e-04
# Epoch 77: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.5816e-04 - mean_squared_error: 1.2363e-04 - val_loss: 0.1741 - val_mean_squared_error: 0.0870
# Epoch 78/300
# 49/51 [===========================>..] - ETA: 0s - loss: 2.0960e-04 - mean_squared_error: 1.6738e-04
# Epoch 78: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 2.1184e-04 - mean_squared_error: 1.6703e-04 - val_loss: 0.0643 - val_mean_squared_error: 0.0321
# Epoch 79/300
# 51/51 [==============================] - ETA: 0s - loss: 1.2800e-04 - mean_squared_error: 1.0263e-04
# Epoch 79: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.2800e-04 - mean_squared_error: 1.0263e-04 - val_loss: 0.0994 - val_mean_squared_error: 0.0497
# Epoch 80/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.5562e-04 - mean_squared_error: 1.2194e-04
# Epoch 80: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.5704e-04 - mean_squared_error: 1.2165e-04 - val_loss: 0.1081 - val_mean_squared_error: 0.0541
# Epoch 81/300
# 51/51 [==============================] - ETA: 0s - loss: 1.5774e-04 - mean_squared_error: 1.2811e-04
# Epoch 81: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.5774e-04 - mean_squared_error: 1.2811e-04 - val_loss: 0.1018 - val_mean_squared_error: 0.0509
# Epoch 82/300
# 51/51 [==============================] - ETA: 0s - loss: 1.6320e-04 - mean_squared_error: 1.3047e-04
# Epoch 82: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.6320e-04 - mean_squared_error: 1.3047e-04 - val_loss: 0.1415 - val_mean_squared_error: 0.0708
# Epoch 83/300
# 51/51 [==============================] - ETA: 0s - loss: 1.7236e-04 - mean_squared_error: 1.3969e-04
# Epoch 83: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.7236e-04 - mean_squared_error: 1.3969e-04 - val_loss: 0.0982 - val_mean_squared_error: 0.0491
# Epoch 84/300
# 51/51 [==============================] - ETA: 0s - loss: 1.4847e-04 - mean_squared_error: 1.2011e-04
# Epoch 84: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.4847e-04 - mean_squared_error: 1.2011e-04 - val_loss: 0.1377 - val_mean_squared_error: 0.0689
# Epoch 85/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.7961e-04 - mean_squared_error: 1.3823e-04
# Epoch 85: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.7952e-04 - mean_squared_error: 1.3705e-04 - val_loss: 0.1389 - val_mean_squared_error: 0.0695
# Epoch 86/300
# 51/51 [==============================] - ETA: 0s - loss: 2.0369e-04 - mean_squared_error: 1.6198e-04
# Epoch 86: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 2.0369e-04 - mean_squared_error: 1.6198e-04 - val_loss: 0.0406 - val_mean_squared_error: 0.0203
# Epoch 87/300
# 51/51 [==============================] - ETA: 0s - loss: 1.7752e-04 - mean_squared_error: 1.3459e-04
# Epoch 87: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.7752e-04 - mean_squared_error: 1.3459e-04 - val_loss: 0.1365 - val_mean_squared_error: 0.0682
# Epoch 88/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.8251e-04 - mean_squared_error: 1.4092e-04
# Epoch 88: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.8392e-04 - mean_squared_error: 1.4047e-04 - val_loss: 0.0602 - val_mean_squared_error: 0.0301
# Epoch 89/300
# 51/51 [==============================] - ETA: 0s - loss: 1.3856e-04 - mean_squared_error: 1.1282e-04
# Epoch 89: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.3856e-04 - mean_squared_error: 1.1282e-04 - val_loss: 0.0571 - val_mean_squared_error: 0.0285
# Epoch 90/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.4287e-04 - mean_squared_error: 1.1134e-04
# Epoch 90: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.4458e-04 - mean_squared_error: 1.1127e-04 - val_loss: 0.0831 - val_mean_squared_error: 0.0416
# Epoch 91/300
# 51/51 [==============================] - ETA: 0s - loss: 1.6155e-04 - mean_squared_error: 1.2735e-04
# Epoch 91: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.6155e-04 - mean_squared_error: 1.2735e-04 - val_loss: 0.0789 - val_mean_squared_error: 0.0394
# Epoch 92/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.4304e-04 - mean_squared_error: 1.1937e-04
# Epoch 92: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.4813e-04 - mean_squared_error: 1.2072e-04 - val_loss: 0.0574 - val_mean_squared_error: 0.0287
# Epoch 93/300
# 51/51 [==============================] - ETA: 0s - loss: 1.6720e-04 - mean_squared_error: 1.2791e-04
# Epoch 93: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.6720e-04 - mean_squared_error: 1.2791e-04 - val_loss: 0.1018 - val_mean_squared_error: 0.0509
# Epoch 94/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.7310e-04 - mean_squared_error: 1.3843e-04
# Epoch 94: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.7554e-04 - mean_squared_error: 1.3839e-04 - val_loss: 0.0604 - val_mean_squared_error: 0.0302
# Epoch 95/300
# 51/51 [==============================] - ETA: 0s - loss: 1.2826e-04 - mean_squared_error: 1.0509e-04
# Epoch 95: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.2826e-04 - mean_squared_error: 1.0509e-04 - val_loss: 0.0634 - val_mean_squared_error: 0.0317
# Epoch 96/300
# 51/51 [==============================] - ETA: 0s - loss: 1.5760e-04 - mean_squared_error: 1.2168e-04
# Epoch 96: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.5760e-04 - mean_squared_error: 1.2168e-04 - val_loss: 0.0949 - val_mean_squared_error: 0.0475
# Epoch 97/300
# 49/51 [===========================>..] - ETA: 0s - loss: 1.6520e-04 - mean_squared_error: 1.3429e-04
# Epoch 97: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.6782e-04 - mean_squared_error: 1.3432e-04 - val_loss: 0.0594 - val_mean_squared_error: 0.0297
# Epoch 98/300
# 51/51 [==============================] - ETA: 0s - loss: 1.2908e-04 - mean_squared_error: 1.0556e-04
# Epoch 98: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.2908e-04 - mean_squared_error: 1.0556e-04 - val_loss: 0.0723 - val_mean_squared_error: 0.0361
# Epoch 99/300
# 51/51 [==============================] - ETA: 0s - loss: 1.4816e-04 - mean_squared_error: 1.1581e-04
# Epoch 99: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.4816e-04 - mean_squared_error: 1.1581e-04 - val_loss: 0.1025 - val_mean_squared_error: 0.0512
# Epoch 100/300
# 51/51 [==============================] - ETA: 0s - loss: 1.6611e-04 - mean_squared_error: 1.3310e-04
# Epoch 100: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.6611e-04 - mean_squared_error: 1.3310e-04 - val_loss: 0.0465 - val_mean_squared_error: 0.0232
# Epoch 101/300
# 51/51 [==============================] - ETA: 0s - loss: 1.2717e-04 - mean_squared_error: 1.0192e-04
# Epoch 101: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.2717e-04 - mean_squared_error: 1.0192e-04 - val_loss: 0.0743 - val_mean_squared_error: 0.0372
# Epoch 102/300
# 51/51 [==============================] - ETA: 0s - loss: 1.4507e-04 - mean_squared_error: 1.1367e-04
# Epoch 102: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.4507e-04 - mean_squared_error: 1.1367e-04 - val_loss: 0.0607 - val_mean_squared_error: 0.0304
# Epoch 103/300
# 51/51 [==============================] - ETA: 0s - loss: 1.4344e-04 - mean_squared_error: 1.0440e-04
# Epoch 103: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.4344e-04 - mean_squared_error: 1.0440e-04 - val_loss: 0.0238 - val_mean_squared_error: 0.0119
# Epoch 104/300
# 51/51 [==============================] - ETA: 0s - loss: 1.3472e-04 - mean_squared_error: 1.0264e-04
# Epoch 104: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.3472e-04 - mean_squared_error: 1.0264e-04 - val_loss: 0.0878 - val_mean_squared_error: 0.0439
# Epoch 105/300
# 51/51 [==============================] - ETA: 0s - loss: 1.6095e-04 - mean_squared_error: 1.2454e-04
# Epoch 105: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.6095e-04 - mean_squared_error: 1.2454e-04 - val_loss: 0.0580 - val_mean_squared_error: 0.0290
# Epoch 106/300
# 51/51 [==============================] - ETA: 0s - loss: 1.0545e-04 - mean_squared_error: 7.9225e-05
# Epoch 106: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.0545e-04 - mean_squared_error: 7.9225e-05 - val_loss: 0.0547 - val_mean_squared_error: 0.0273
# Epoch 107/300
# 51/51 [==============================] - ETA: 0s - loss: 9.8370e-05 - mean_squared_error: 7.3869e-05
# Epoch 107: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 9.8370e-05 - mean_squared_error: 7.3869e-05 - val_loss: 0.0590 - val_mean_squared_error: 0.0295
# Epoch 108/300
# 51/51 [==============================] - ETA: 0s - loss: 1.0005e-04 - mean_squared_error: 7.6086e-05
# Epoch 108: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 1.0005e-04 - mean_squared_error: 7.6086e-05 - val_loss: 0.0572 - val_mean_squared_error: 0.0286
# Epoch 109/300
# 49/51 [===========================>..] - ETA: 0s - loss: 8.3803e-05 - mean_squared_error: 6.7746e-05
# Epoch 109: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 9.6289e-05 - mean_squared_error: 7.3299e-05 - val_loss: 0.0566 - val_mean_squared_error: 0.0283
# Epoch 110/300
# 49/51 [===========================>..] - ETA: 0s - loss: 8.5714e-05 - mean_squared_error: 6.9564e-05
# Epoch 110: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 9.7675e-05 - mean_squared_error: 7.4831e-05 - val_loss: 0.0570 - val_mean_squared_error: 0.0285
# Epoch 111/300
# 51/51 [==============================] - ETA: 0s - loss: 9.5041e-05 - mean_squared_error: 7.2657e-05
# Epoch 111: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 9.5041e-05 - mean_squared_error: 7.2657e-05 - val_loss: 0.0541 - val_mean_squared_error: 0.0271
# Epoch 112/300
# 51/51 [==============================] - ETA: 0s - loss: 9.4451e-05 - mean_squared_error: 7.2312e-05
# Epoch 112: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 34ms/step - loss: 9.4451e-05 - mean_squared_error: 7.2312e-05 - val_loss: 0.0523 - val_mean_squared_error: 0.0262
# Epoch 113/300
# 51/51 [==============================] - ETA: 0s - loss: 9.2088e-05 - mean_squared_error: 7.0636e-05
# Epoch 113: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 36ms/step - loss: 9.2088e-05 - mean_squared_error: 7.0636e-05 - val_loss: 0.0512 - val_mean_squared_error: 0.0256
# Epoch 114/300
# 51/51 [==============================] - ETA: 0s - loss: 9.8052e-05 - mean_squared_error: 7.5195e-05
# Epoch 114: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 9.8052e-05 - mean_squared_error: 7.5195e-05 - val_loss: 0.0437 - val_mean_squared_error: 0.0218
# Epoch 115/300
# 51/51 [==============================] - ETA: 0s - loss: 9.8856e-05 - mean_squared_error: 7.6986e-05
# Epoch 115: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 36ms/step - loss: 9.8856e-05 - mean_squared_error: 7.6986e-05 - val_loss: 0.0302 - val_mean_squared_error: 0.0151
# Epoch 116/300
# 51/51 [==============================] - ETA: 0s - loss: 1.0014e-04 - mean_squared_error: 7.8670e-05
# Epoch 116: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.0014e-04 - mean_squared_error: 7.8670e-05 - val_loss: 0.0435 - val_mean_squared_error: 0.0217
# Epoch 117/300
# 51/51 [==============================] - ETA: 0s - loss: 1.0223e-04 - mean_squared_error: 7.9474e-05
# Epoch 117: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.0223e-04 - mean_squared_error: 7.9474e-05 - val_loss: 0.0612 - val_mean_squared_error: 0.0306
# Epoch 118/300
# 51/51 [==============================] - ETA: 0s - loss: 1.1319e-04 - mean_squared_error: 8.5542e-05
# Epoch 118: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.1319e-04 - mean_squared_error: 8.5542e-05 - val_loss: 0.0397 - val_mean_squared_error: 0.0199
# Epoch 119/300
# 51/51 [==============================] - ETA: 0s - loss: 1.1301e-04 - mean_squared_error: 8.9568e-05
# Epoch 119: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.1301e-04 - mean_squared_error: 8.9568e-05 - val_loss: 0.0195 - val_mean_squared_error: 0.0098
# Epoch 120/300
# 51/51 [==============================] - ETA: 0s - loss: 1.1697e-04 - mean_squared_error: 8.8269e-05
# Epoch 120: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.1697e-04 - mean_squared_error: 8.8269e-05 - val_loss: 0.0651 - val_mean_squared_error: 0.0326
# Epoch 121/300
# 51/51 [==============================] - ETA: 0s - loss: 1.2157e-04 - mean_squared_error: 9.3936e-05
# Epoch 121: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 36ms/step - loss: 1.2157e-04 - mean_squared_error: 9.3936e-05 - val_loss: 0.0421 - val_mean_squared_error: 0.0210
# Epoch 122/300
# 51/51 [==============================] - ETA: 0s - loss: 9.9307e-05 - mean_squared_error: 7.8655e-05
# Epoch 122: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 9.9307e-05 - mean_squared_error: 7.8655e-05 - val_loss: 0.0338 - val_mean_squared_error: 0.0169
# Epoch 123/300
# 51/51 [==============================] - ETA: 0s - loss: 9.6797e-05 - mean_squared_error: 7.5348e-05
# Epoch 123: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 36ms/step - loss: 9.6797e-05 - mean_squared_error: 7.5348e-05 - val_loss: 0.0294 - val_mean_squared_error: 0.0147
# Epoch 124/300
# 51/51 [==============================] - ETA: 0s - loss: 9.6971e-05 - mean_squared_error: 7.7052e-05
# Epoch 124: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 36ms/step - loss: 9.6971e-05 - mean_squared_error: 7.7052e-05 - val_loss: 0.0281 - val_mean_squared_error: 0.0140
# Epoch 125/300
# 51/51 [==============================] - ETA: 0s - loss: 1.0692e-04 - mean_squared_error: 8.3790e-05
# Epoch 125: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.0692e-04 - mean_squared_error: 8.3790e-05 - val_loss: 0.0496 - val_mean_squared_error: 0.0248
# Epoch 126/300
# 51/51 [==============================] - ETA: 0s - loss: 1.0921e-04 - mean_squared_error: 8.5719e-05
# Epoch 126: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 36ms/step - loss: 1.0921e-04 - mean_squared_error: 8.5719e-05 - val_loss: 0.0511 - val_mean_squared_error: 0.0255
# Epoch 127/300
# 51/51 [==============================] - ETA: 0s - loss: 1.0801e-04 - mean_squared_error: 8.3194e-05
# Epoch 127: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 36ms/step - loss: 1.0801e-04 - mean_squared_error: 8.3194e-05 - val_loss: 0.0373 - val_mean_squared_error: 0.0187
# Epoch 128/300
# 51/51 [==============================] - ETA: 0s - loss: 1.0968e-04 - mean_squared_error: 8.7500e-05
# Epoch 128: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.0968e-04 - mean_squared_error: 8.7500e-05 - val_loss: 0.0160 - val_mean_squared_error: 0.0080
# Epoch 129/300
# 51/51 [==============================] - ETA: 0s - loss: 1.1842e-04 - mean_squared_error: 9.0696e-05
# Epoch 129: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 36ms/step - loss: 1.1842e-04 - mean_squared_error: 9.0696e-05 - val_loss: 0.0555 - val_mean_squared_error: 0.0278
# Epoch 130/300
# 51/51 [==============================] - ETA: 0s - loss: 1.1553e-04 - mean_squared_error: 8.9554e-05
# Epoch 130: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 1.1553e-04 - mean_squared_error: 8.9554e-05 - val_loss: 0.0492 - val_mean_squared_error: 0.0246
# Epoch 131/300
# 51/51 [==============================] - ETA: 0s - loss: 9.5907e-05 - mean_squared_error: 7.5913e-05
# Epoch 131: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 36ms/step - loss: 9.5907e-05 - mean_squared_error: 7.5913e-05 - val_loss: 0.0484 - val_mean_squared_error: 0.0242
# Epoch 132/300
# 51/51 [==============================] - ETA: 0s - loss: 1.0035e-04 - mean_squared_error: 7.8802e-05
# Epoch 132: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 36ms/step - loss: 1.0035e-04 - mean_squared_error: 7.8802e-05 - val_loss: 0.0412 - val_mean_squared_error: 0.0206
# Epoch 133/300
# 51/51 [==============================] - ETA: 0s - loss: 9.8251e-05 - mean_squared_error: 7.6560e-05
# Epoch 133: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 35ms/step - loss: 9.8251e-05 - mean_squared_error: 7.6560e-05 - val_loss: 0.0362 - val_mean_squared_error: 0.0181
# Epoch 134/300
# 51/51 [==============================] - ETA: 0s - loss: 1.0014e-04 - mean_squared_error: 7.8050e-05
# Epoch 134: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 36ms/step - loss: 1.0014e-04 - mean_squared_error: 7.8050e-05 - val_loss: 0.0255 - val_mean_squared_error: 0.0127
# Epoch 135/300
# 51/51 [==============================] - ETA: 0s - loss: 9.3972e-05 - mean_squared_error: 7.4875e-05
# Epoch 135: val_mean_squared_error did not improve from 0.00213
# 51/51 [==============================] - 2s 36ms/step - loss: 9.3972e-05 - mean_squared_error: 7.4875e-05 - val_loss: 0.0257 - val_mean_squared_error: 0.0128

# %%
### Plotting Loss vs Validation loss
import matplotlib.pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(loss))

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()


plt.show()

# %%
from keras.models import load_model
model_from_saved_checkpoint_2_15 = load_model('/content/my_best_model_2_15.hdf5', custom_objects={'custom_loss':                   
custom_loss})

# %%
### Lets Do the prediction and check performance metrics
train_predict=model_from_saved_checkpoint_2_15.predict(X_train)
test_predict=model_from_saved_checkpoint_2_15.predict(X_test)
train_predict.shape, test_predict.shape
# Out:
# ((1611, 1), (1070, 1))

# %%
# Model Evaluation
# Transform back to original form

train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
original_ytrain = scaler.inverse_transform(y_train.reshape(-1,1)) 
original_ytest = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
# !pip install -U kaleido
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaleido in /usr/local/lib/python3.7/dist-packages (0.2.1)

# %%
# !pip install plotly>=4.0.0
# !wget https://github.com/plotly/orca/releases/download/v1.2.1/orca-1.2.1-x86_64.AppImage -O /usr/local/bin/orca
# !chmod +x /usr/local/bin/orca
# !apt-get install xvfb libgtk2.0-0 libgconf-2-4
# Out:
# /usr/local/bin/orca: Text file busy
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libgtk2.0-0 is already the newest version (2.24.32-1ubuntu1).
# libgconf-2-4 is already the newest version (3.2.6-4ubuntu1).
# xvfb is already the newest version (2:1.19.6-1ubuntu4.11).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.

# %%
# !pip install gitly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gitly in /usr/local/lib/python3.7/dist-packages (1.1.4)
# Requirement already satisfied: plotly>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from gitly) (5.5.0)
# Requirement already satisfied: kaleido in /usr/local/lib/python3.7/dist-packages (from gitly) (0.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=4.9.0->gitly) (8.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly>=4.9.0->gitly) (1.15.0)

# %%
from gitly.colab.plot import GitlyPlotter

# %%
gitly = GitlyPlotter('colab')

# %%
# shift train predictions for plotting
# !pip install -U kaleido
look_back=time_step
trainPredictPlot = np.empty_like(closedf)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
print("Train predicted data: ", trainPredictPlot.shape)

# shift test predictions for plotting
testPredictPlot = np.empty_like(closedf)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(closedf)-1, :] = test_predict
print("Test predicted data: ", testPredictPlot.shape)

names = cycle(['Original close price','Train predicted close price','Test predicted close price'])


plotdf = pd.DataFrame({'date': close_stock['Date'],
                       'original_close': close_stock['Close'],
                      'train_predicted_close': trainPredictPlot.reshape(1,-1)[0].tolist(),
                      'test_predicted_close': testPredictPlot.reshape(1,-1)[0].tolist()})

fig = px.line(plotdf,x=plotdf['date'], y=[plotdf['original_close'],plotdf['train_predicted_close'],
                                          plotdf['test_predicted_close']],
              labels={'value':'Stock price','date': 'Date'})
fig.update_layout(title_text='Comparision between original close price vs predicted close price',
                  plot_bgcolor='white', font_size=15, font_color='black', legend_title_text='Close Price')
fig.for_each_trace(lambda t:  t.update(name = next(names)))

fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.show()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaleido in /usr/local/lib/python3.7/dist-packages (0.2.1)
# Train predicted data:  (2713, 1)
# Test predicted data:  (2713, 1)

# %%
# shift train predictions for plotting

look_back=time_step
trainPredictPlot = np.empty_like(closedf)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
print("Train predicted data: ", trainPredictPlot.shape)

# shift test predictions for plotting
testPredictPlot = np.empty_like(closedf)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(closedf)-1, :] = test_predict
print("Test predicted data: ", testPredictPlot.shape)

names = cycle(['Original close price','Train predicted close price','Test predicted close price'])


plotdf = pd.DataFrame({'date': close_stock['Date'],
                       'original_close': close_stock['Close'],
                      'train_predicted_close': trainPredictPlot.reshape(1,-1)[0].tolist(),
                      'test_predicted_close': testPredictPlot.reshape(1,-1)[0].tolist()})

fig = px.line(plotdf,x=plotdf['date'], y=[plotdf['original_close'],plotdf['train_predicted_close'],
                                          plotdf['test_predicted_close']],
              labels={'value':'Stock price','date': 'Date'})
fig.update_layout(title_text='Comparision between original close price vs predicted close price',
                  plot_bgcolor='white', font_size=15, font_color='black', legend_title_text='Close Price')
fig.for_each_trace(lambda t:  t.update(name = next(names)))

fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.show()
# Out:
# Train predicted data:  (2713, 1)
# Test predicted data:  (2713, 1)

# %%
# shift train predictions for plotting

look_back=time_step
trainPredictPlot = np.empty_like(closedf)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
print("Train predicted data: ", trainPredictPlot.shape)

# shift test predictions for plotting
testPredictPlot = np.empty_like(closedf)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(closedf)-1, :] = test_predict
print("Test predicted data: ", testPredictPlot.shape)

names = cycle(['Original close price','Train predicted close price','Test predicted close price'])


plotdf = pd.DataFrame({'date': close_stock['Date'],
                       'original_close': close_stock['Close'],
                      'train_predicted_close': trainPredictPlot.reshape(1,-1)[0].tolist(),
                      'test_predicted_close': testPredictPlot.reshape(1,-1)[0].tolist()})

fig = px.line(plotdf,x=plotdf['date'], y=[plotdf['original_close'],plotdf['train_predicted_close'],
                                          plotdf['test_predicted_close']],
              labels={'value':'Stock price','date': 'Date'})
fig.update_layout(title_text='Comparision between original close price vs predicted close price',
                  plot_bgcolor='white', font_size=15, font_color='black', legend_title_text='Close Price')
fig.for_each_trace(lambda t:  t.update(name = next(names)))

fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.show()
# Out:
# Train predicted data:  (2713, 1)
# Test predicted data:  (2713, 1)
